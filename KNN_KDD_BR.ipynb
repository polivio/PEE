# %% [markdown]
# <a href="https://colab.research.google.com/github/polivio/PEE/blob/master/KNN_KDD_BR.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# https://www.kaggle.com/c/kddbr-2019/data

# KNN KDD BR -Polivio
import numpy as np
from sklearn import preprocessing, neighbors
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
# preprocessing # blob # raw
train = pd.read_csv('https://github.com/polivio/PEE/raw/master/Training_grouped.csv')
test = pd.read_csv('https://github.com/polivio/PEE/raw/master/Test_grouped.csv')

#df.replace('?', -99999, inplace= True)
#df.drop(['id'] ,1, inplace= True)

train.head()
# Out:
#    Unnamed: 0  ...  traininglabelorder.score
# 0           2  ...                  0.009647
# 1           3  ...                  0.842084
# 2           5  ...                  0.744601
# 3           6  ...                  0.842084
# 4           9  ...                  0.944177
#
# [5 rows x 21 columns]

# %%
train.columns
# Out:
# Index(['Unnamed: 0', 'traininglabelorder.scatterplotID', 'qtde.ponto',
#        'Negative', 'Sample', 'mean.signalX', 'sd.signalX', 'var.signalX',
#        'kurtosis.signalX', 'skew.signalX', 'mean.signalY', 'sd.signalY',
#        'var.signalY', 'kurtosis.signalY', 'skew.signalY', 'L', 'X', 'XY', 'Y',
#        'mean.silhouette', 'traininglabelorder.score'],
#       dtype='object')

# %%
train = train.loc[:,['traininglabelorder.scatterplotID', 'qtde.ponto', 
       'mean.signalX', 'sd.signalX', 'kurtosis.signalX',
      'mean.signalY', 'sd.signalY', 
       'kurtosis.signalY', 'L', 'X', 'XY', 'Y',
       'mean.silhouette']]



train.head(20)
# Out:
#     traininglabelorder.scatterplotID  qtde.ponto  ...      Y  mean.silhouette
# 0                                  2         365  ...    NaN         0.840146
# 1                                  3         384  ...  249.0         0.964427
# 2                                  5         373  ...  206.0         0.936210
# 3                                  6         384  ...   90.0         0.896070
# 4                                  9         383  ...  201.0         0.952810
# 5                                 10         384  ...  368.0         0.968487
# 6                                 12         362  ...  106.0         0.913787
# 7                                 13         200  ...  170.0         0.916503
# 8                                 16         384  ...   54.0         0.956756
# 9                                 17         154  ...  144.0         0.949731
# 10                                19         384  ...  146.0         0.955443
# 11                                20         384  ...   22.0         0.829714
# 12                                24         384  ...  110.0         0.937572
# 13                                25         304  ...  152.0         0.907024
# 14                                26         384  ...  365.0         0.940349
# 15                                28         384  ...   91.0         0.882495
# 16                                30         384  ...   80.0         0.485581
# 17                                33         167  ...   85.0         0.954536
# 18                                34         383  ...   48.0         0.957652
# 19                                35         374  ...  204.0         0.946961
#
# [20 rows x 13 columns]

# %%
test.columns
# Out:
# Index(['Unnamed: 0', 'testorder.ID', 'qtde.ponto', 'Negative', 'Sample',
#        'mean.signalX', 'sd.signalX', 'var.signalX', 'kurtosis.signalX',
#        'skew.signalX', 'mean.signalY', 'sd.signalY', 'var.signalY',
#        'kurtosis.signalY', 'skew.signalY', 'L', 'X', 'XY', 'Y',
#        'mean.silhouette'],
#       dtype='object')

# %%
test = test.loc[:,['testorder.ID', 'qtde.ponto', 
       'mean.signalX', 'sd.signalX', 'kurtosis.signalX',
      'mean.signalY', 'sd.signalY', 
       'kurtosis.signalY', 'L', 'X', 'XY', 'Y',
       'mean.silhouette']]
test.head(20)
# Out:
#     testorder.ID  qtde.ponto  mean.signalX  ...     XY      Y  mean.silhouette
# 0              1         384   2929.713542  ...  167.0   94.0         0.916505
# 1             22         384   1409.484375  ...  189.0   99.0         0.891220
# 2             27         382   2031.329843  ...   73.0  254.0         0.947689
# 3             31         370   2900.078378  ...   10.0  185.0         0.954000
# 4             55         384   2567.598958  ...  182.0   92.0         0.829513
# 5             78         384   4270.281250  ...  221.0  124.0         0.419574
# 6             80         373   2978.777480  ...   10.0   91.0         0.896077
# 7             89         384    757.755208  ...  361.0   10.0         0.858830
# 8            103         112   1365.607143  ...   36.0   72.0         0.896741
# 9            104         212   1061.561321  ...   64.0  120.0         0.953351
# 10           116         375   2603.053333  ...   20.0  216.0         0.952802
# 11           129         384    468.973958  ...   27.0  188.0         0.897665
# 12           131         371   1478.663073  ...    NaN   47.0         0.952402
# 13           133         309   1458.689320  ...    2.0  169.0         0.949457
# 14           141         384   2747.588542  ...  156.0   77.0         0.890903
# 15           147         384   1796.411458  ...   18.0  248.0         0.894931
# 16           149         384    444.885417  ...    4.0  368.0         0.926698
# 17           158         384   2706.635417  ...  114.0   81.0         0.736624
# 18           161         384   2722.815104  ...   11.0  181.0         0.921240
# 19           172         380   2071.052632  ...  192.0   79.0         0.900564
#
# [20 rows x 13 columns]

# %%
# https://stackoverflow.com/questions/49420427/pandas-df-fillnadf-mean-not-working-on-multiindex-dataframe

train = train.reset_index()

train = train.fillna(0)
train.head(20)
# Out:
#     level_0  index  ...  mean.silhouette  traininglabelorder.score
# 0         0      0  ...         0.840146                  0.009647
# 1         1      1  ...         0.964427                  0.842084
# 2         2      2  ...         0.936210                  0.744601
# 3         3      3  ...         0.896070                  0.842084
# 4         4      4  ...         0.952810                  0.944177
# 5         5      5  ...         0.968487                  1.000000
# 6         6      6  ...         0.913787                  0.578706
# 7         7      7  ...         0.916503                  1.000000
# 8         8      8  ...         0.956756                  0.944319
# 9         9      9  ...         0.949731                  0.751477
# 10       10     10  ...         0.955443                  1.000000
# 11       11     11  ...         0.829714                  0.283536
# 12       12     12  ...         0.937572                  0.474833
# 13       13     13  ...         0.907024                  0.647776
# 14       14     14  ...         0.940349                  0.795196
# 15       15     15  ...         0.882495                  1.000000
# 16       16     16  ...         0.485581                  0.006463
# 17       17     17  ...         0.954536                  0.768378
# 18       18     18  ...         0.957652                  0.944177
# 19       19     19  ...         0.946961                  0.745189
#
# [20 rows x 14 columns]

# %%
test = test.reset_index()

test = test.fillna(train.mean())
test.head(20)
# Out:
#     index  testorder.ID  qtde.ponto  ...          XY      Y  mean.silhouette
# 0       0             1         384  ...  167.000000   94.0         0.916505
# 1       1            22         384  ...  189.000000   99.0         0.891220
# 2       2            27         382  ...   73.000000  254.0         0.947689
# 3       3            31         370  ...   10.000000  185.0         0.954000
# 4       4            55         384  ...  182.000000   92.0         0.829513
# 5       5            78         384  ...  221.000000  124.0         0.419574
# 6       6            80         373  ...   10.000000   91.0         0.896077
# 7       7            89         384  ...  361.000000   10.0         0.858830
# 8       8           103         112  ...   36.000000   72.0         0.896741
# 9       9           104         212  ...   64.000000  120.0         0.953351
# 10     10           116         375  ...   20.000000  216.0         0.952802
# 11     11           129         384  ...   27.000000  188.0         0.897665
# 12     12           131         371  ...   80.421065   47.0         0.952402
# 13     13           133         309  ...    2.000000  169.0         0.949457
# 14     14           141         384  ...  156.000000   77.0         0.890903
# 15     15           147         384  ...   18.000000  248.0         0.894931
# 16     16           149         384  ...    4.000000  368.0         0.926698
# 17     17           158         384  ...  114.000000   81.0         0.736624
# 18     18           161         384  ...   11.000000  181.0         0.921240
# 19     19           172         380  ...  192.000000   79.0         0.900564
#
# [20 rows x 20 columns]

# %%
# X = features ; y = lable
X_train = np.array(train.drop(['traininglabelorder.score'], 1))
y_train = np.array(train['traininglabelorder.score'])

X_test = np.array(test.drop(['traininglabelorder.score'], 1))
y_test = np.array(test['traininglabelorder.score'])

#X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
# classsifiers KNN

clf = neighbors.KNeighborsClassifier(n_neighbors=4)
clf.fit(X_train , y_train)

accuracy = clf.score(X_test, y_test)

print(accuracy)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-20-9a29108e1a1e> in <module>()
#       1
#       2 clf = neighbors.KNeighborsClassifier(n_neighbors=4)
# ----> 3 clf.fit(X_train , y_train)
#       4
#       5 accuracy = clf.score(X_test, y_test)
#
# /usr/local/lib/python3.6/dist-packages/sklearn/neighbors/base.py in fit(self, X, y)
#     890         """
#     891         if not isinstance(X, (KDTree, BallTree)):
# --> 892             X, y = check_X_y(X, y, "csr", multi_output=True)
#     893
#     894         if y.ndim == 1 or y.ndim == 2 and y.shape[1] == 1:
#
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
#     717                     ensure_min_features=ensure_min_features,
#     718                     warn_on_dtype=warn_on_dtype,
# --> 719                     estimator=estimator)
#     720     if multi_output:
#     721         y = check_array(y, 'csr', force_all_finite=True, ensure_2d=False,
#
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     540         if force_all_finite:
#     541             _assert_all_finite(array,
# --> 542                                allow_nan=force_all_finite == 'allow-nan')
#     543
#     544     if ensure_min_samples > 0:
#
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/validation.py in _assert_all_finite(X, allow_nan)
#      54                 not allow_nan and not np.isfinite(X).all()):
#      55             type_err = 'infinity' if allow_nan else 'NaN, infinity'
# ---> 56             raise ValueError(msg_err.format(type_err, X.dtype))
#      57     # for object dtype data, we only check for NaNs (GH-13254)
#      58     elif X.dtype == np.dtype('object') and not allow_nan:
#
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').

# %%
#example_measures = np.array([4,2,1,1,1,2,3,2,1]) 

example_measures = np.array([[4,2,1,1,1,2,3,2,1], [4,2,1,2,2,2,3,2,1]])
example_measures = example_measures.reshape(len(example_measures),-1) 
prediction = clf.predict(example_measures)
print(prediction)

# class 2 = ben 2 4 = maligno
# Out:
# [2 2]
